# %% [markdown]
# ## Model Ideas:
# - naive bayes with SVM
#     - text cleaning: remove stop words, punctuation, also try with varying levels of processing
# - attention modeling with transfer learning
# - logistic regression
#
# ### for next time:
# - read up on tf-idf
# - naive bayes / SVM
# - high level understanding of nltk

# %% [markdown]
# ### outline of steps:
# #### preprocessing
# - remove blank rows
# - change all text to lowercase
# - tokenization: break stream of text into list of words or sentences (nltk.word_tokenize, nltk.sent_tokenize)
# - remove stopwords and non-alpha text
# - word stemming/lemmatization: convert words to their root
# - in original dataset, need a column of pre-processed text that has list of lemmatized/stemmed words, no puncuation
#
# #### encoding / word vectorization
# - encode target variable to a number (sklearn.preprocessing.LabelEncoder)
# - calculate tf-idf on the column of preprocessed text
# - tf-idf output gives you (row, integer number of each word) tf-idf_score
#
# #### modeling
# - fit naive_bayes.MultinomiaNB() on tf-idf matrix (result of tf-idf transformation)
# - calculate predictions, accuracy score

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %%
path = '/Users/christinejiang/Documents/Python/data/tweet-sentiment-extraction/'
train = pd.read_csv(path+'train.csv')
test = pd.read_csv(path+'test.csv')
submission = pd.read_csv(path+'sample_submission.csv')

# %%
train.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
temp = train.groupby('selected_text').count().sort_values('sentiment',ascending=False).head(20)
temp.style.background_gradient(cmap='mako_r')
# Out:
# <style  type="text/css" >
#     #T_fa9423d2_9486_11ea_8c26_acde48001122row0_col0 {
#             background-color:  #0b0405;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row0_col1 {
#             background-color:  #0b0405;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row0_col2 {
#             background-color:  #0b0405;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row1_col0 {
#             background-color:  #231526;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row1_col1 {
#             background-color:  #231526;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row1_col2 {
#             background-color:  #231526;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row2_col0 {
#             background-color:  #3c3162;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row2_col1 {
#             background-color:  #3c3162;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row2_col2 {
#             background-color:  #3c3162;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row3_col0 {
#             background-color:  #3d5195;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row3_col1 {
#             background-color:  #3d5195;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row3_col2 {
#             background-color:  #3d5195;
#             color:  #f1f1f1;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row4_col0 {
#             background-color:  #3497a9;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row4_col1 {
#             background-color:  #3497a9;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row4_col2 {
#             background-color:  #3497a9;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row5_col0 {
#             background-color:  #37a5ac;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row5_col1 {
#             background-color:  #37a5ac;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row5_col2 {
#             background-color:  #37a5ac;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row6_col0 {
#             background-color:  #3db3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row6_col1 {
#             background-color:  #3db3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row6_col2 {
#             background-color:  #3db3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row7_col0 {
#             background-color:  #3fb6ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row7_col1 {
#             background-color:  #3fb6ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row7_col2 {
#             background-color:  #3fb6ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row8_col0 {
#             background-color:  #4cc3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row8_col1 {
#             background-color:  #4cc3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row8_col2 {
#             background-color:  #4cc3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row9_col0 {
#             background-color:  #4cc3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row9_col1 {
#             background-color:  #4cc3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row9_col2 {
#             background-color:  #4cc3ad;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row10_col0 {
#             background-color:  #79d6ae;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row10_col1 {
#             background-color:  #79d6ae;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row10_col2 {
#             background-color:  #79d6ae;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row11_col0 {
#             background-color:  #7cd6af;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row11_col1 {
#             background-color:  #7cd6af;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row11_col2 {
#             background-color:  #7cd6af;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row12_col0 {
#             background-color:  #94dcb5;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row12_col1 {
#             background-color:  #94dcb5;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row12_col2 {
#             background-color:  #94dcb5;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row13_col0 {
#             background-color:  #99ddb6;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row13_col1 {
#             background-color:  #99ddb6;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row13_col2 {
#             background-color:  #99ddb6;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row14_col0 {
#             background-color:  #99ddb6;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row14_col1 {
#             background-color:  #99ddb6;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row14_col2 {
#             background-color:  #99ddb6;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row15_col0 {
#             background-color:  #abe2be;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row15_col1 {
#             background-color:  #abe2be;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row15_col2 {
#             background-color:  #abe2be;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row16_col0 {
#             background-color:  #b2e4c2;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row16_col1 {
#             background-color:  #b2e4c2;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row16_col2 {
#             background-color:  #b2e4c2;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row17_col0 {
#             background-color:  #b9e6c7;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row17_col1 {
#             background-color:  #b9e6c7;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row17_col2 {
#             background-color:  #b9e6c7;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row18_col0 {
#             background-color:  #c4eacf;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row18_col1 {
#             background-color:  #c4eacf;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row18_col2 {
#             background-color:  #c4eacf;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row19_col0 {
#             background-color:  #def5e5;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row19_col1 {
#             background-color:  #def5e5;
#             color:  #000000;
#         }    #T_fa9423d2_9486_11ea_8c26_acde48001122row19_col2 {
#             background-color:  #def5e5;

# %%
print(f'train shape:{train.shape}')
display(train.head())
print(f'test shape: {test.shape}')
display(test.head())
# Out:
# train shape:(27481, 4)
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
# test shape: (3534, 3)
#        textID                                               text sentiment
# 0  f87dea47db  Last session of the day  http://twitpic.com/67ezh   neutral
# 1  96d74cb729   Shanghai is also really exciting (precisely -...  positive
# 2  eee518ae67  Recession hit Veronique Branquinho, she has to...  negative
# 3  01082688c6                                        happy bday!  positive
# 4  33987a8ee5             http://twitpic.com/4w75p - I like it!!  positive

# %%
test.dtypes
# Out:
# textID       object
# text         object
# sentiment    object
# dtype: object

# %%
corpus = list(train['text'].astype(str))
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
feature_names = vectorizer.get_feature_names()

# %%
print(X)
# Out:
#   (0, 10794)	0.3074369990679438
#   (0, 25304)	0.39019790983682484
#   (0, 12348)	0.332449153509136
#   (0, 19605)	0.7626615488152436
#   (0, 11515)	0.2470890629972583
#   (1, 7808)	0.5082396710971107
#   (1, 20219)	0.4815063372325792
#   (1, 12491)	0.1777785842206892
#   (1, 11735)	0.27636000213407014
#   (1, 26209)	0.16531891177156582
#   (1, 15589)	0.28046379261867355
#   (1, 25527)	0.2590416443756134
#   (1, 20135)	0.2940035182063991
#   (1, 21583)	0.3772705717955796
#   (2, 15185)	0.23247743154143272
#   (2, 5065)	0.7364127040606855
#   (2, 12841)	0.2097338570214545
#   (2, 4664)	0.5686869089975516
#   (2, 16099)	0.19041397500089752
#   (3, 2775)	0.5070657519380314
#   (3, 14060)	0.4708223941249711
#   (3, 12734)	0.594892521062647
#   (3, 25351)	0.3241544027791997
#   (3, 15185)	0.2494742630904795
#   (4, 4689)	0.3171944836114534
#   :	:
#   (27478, 18579)	0.2410399861844931
#   (27478, 22777)	0.21200390526958965
#   (27478, 22342)	0.22878705459482904
#   (27478, 26047)	0.22130032230145363
#   (27478, 10816)	0.14707383594906176
#   (27478, 12868)	0.10464243502667124
#   (27478, 4673)	0.24518043455942673
#   (27478, 9968)	0.11659577107873062
#   (27478, 23138)	0.0871376925342161
#   (27478, 16865)	0.12241526567355675
#   (27478, 26209)	0.21428990876989368
#   (27479, 25780)	0.6906744235072161
#   (27479, 25087)	0.3615631469873274
#   (27479, 12868)	0.5314368187957125
#   (27479, 5150)	0.3313847297053504
#   (27480, 3387)	0.5055197961345305
#   (27480, 9821)	0.4722375978294879
#   (27480, 12161)	0.34301470191293215
#   (27480, 26047)	0.28182684010811754
#   (27480, 23230)	0.18710882621656205
#   (27480, 21362)	0.41948656157443026
#   (27480, 2727)	0.18482191484218105
#   (27480, 23138)	0.11097019781009836
#   (27480, 17009)	0.15930242146079757
#   (27480, 10794)	0.20378041784651255
